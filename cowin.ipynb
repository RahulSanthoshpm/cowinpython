# %%
import requests
import smtplib
import datetime

d=datetime.datetime.today().strftime('%d-%m-%Y')

# 18 or 45
age=18    

# No of people                                                  
tot=3 

# Type of vaccination : COVISHIELD, COVAXIN ...                                                
vacc="COVISHIELD"

# Pincodes list 
pincodes=['673004','673014','673323', '673007', '673009']

FromEmail="rahulpythonprog@gmail.com"    # From Email ID inside double quote
FromEmailPass="Vinayaksp20"         # From Email ID password inside double quote
ToEmail="rahul.santhosh@btech.christuniversity.in"  # To Email ID inside double quote


message = """From: {FromEmail}
To: {ToEmail}
Subject: Vaccine Available
"""
c=0
for k in range(len(pincodes)):
  response = requests.get("https://cdn-api.co-vin.in/api/v2/appointment/sessions/public/calendarByPin?pincode="+str(pincodes[k])+"&date="+str(d))
  for i in range(len(response.json()["centers"])):
    for j in range(len(response.json()["centers"][i-1]["sessions"])):
      if (response.json()["centers"][i-1]["sessions"][j-1]["min_age_limit"]==age and response.json()["centers"][i-1]["sessions"][j-1]["vaccine"]==vacc and response.json()["centers"][i-1]["sessions"][j-1]["available_capacity"] >=tot):
        print(response.json()["centers"][i-1]["name"])
        print(response.json()["centers"][i-1]["sessions"][j-1]["session_id"])
        print(response.json()["centers"][i-1]["sessions"][j-1]["available_capacity"])
        print(response.json()["centers"][i-1]["sessions"][j-1]["min_age_limit"])
        print(response.json()["centers"][i-1]["sessions"][j-1]["vaccine"])
        s = smtplib.SMTP('smtp.gmail.com', 587)
        s.starttls()
        s.login(FromEmail, FromEmailPass)
        str1=response.json()["centers"][i-1]["name"]
        str2=response.json()["centers"][i-1]["sessions"][j-1]["available_capacity"]
        message= (message+ "\n" +	"Center name : " + str1 + "\n"+"Available :" + str(str2) + "\n")
        c=1

if (c==1):
  s.sendmail(FromEmail, ToEmail, message)
  print('Email sent to '+ToEmail+' From '+FromEmail)
  s.quit()
# Out:
# Baby Memorial Hospital
# 075bb696-532a-420a-bb8a-edb60300c1b3
# 3067
# 18
# COVISHIELD
# Baby Memorial Hospital
# 6975ef9a-9a06-4e41-9ce4-c0558b03a365
# 2664
# 18
# COVISHIELD
# PUTHALATH EYE HOSPITAL
# 6cee0e0c-28a9-4b50-9919-797c4438a143
# 265
# 18
# COVISHIELD
# PUTHALATH EYE HOSPITAL
# f6da8d3a-9b94-47c0-9985-d2db1154a63d
# 76
# 18
# COVISHIELD
# PUTHALATH EYE HOSPITAL
# 46c13f22-36e9-422c-8bb1-e335a941a633
# 149
# 18
# COVISHIELD
# Dr Ambadis Calicut Center
# 889e43df-4c2c-4d7d-a974-e87d7ea1c853
# 300
# 18
# COVISHIELD
# IQRAA Clinic Palazhi
# d72b3a0b-82a1-4484-8e10-5764917304a4
# 469
# 18
# COVISHIELD
# CRADLE CALICUT
# dd44b86d-24ce-4a0f-86af-79c9f1669ee3
# 509
# 18
# COVISHIELD
# CRADLE CALICUT
# d1f1f00c-75d2-4c10-bc8b-c8d0f71d9494
# 278
# 18
# COVISHIELD
# MMC Ulliyeri
# 266c0202-4bea-4658-a459-acabcc0381d2
# 183
# 18
# COVISHIELD
# MMC Ulliyeri
# 1998fc5e-491f-40cc-9a7f-ded2d7d5d7d0
# 45
# 18
# COVISHIELD
# MMC Ulliyeri
# 81a38cfa-020a-49cc-88d7-2bb78c7b6db0
# 149
# 18
# COVISHIELD
# MMC Ulliyeri
# 6a21dd42-cb65-4304-a3ba-5726e1d04a92
# 163
# 18
# COVISHIELD
# MMC Ulliyeri
# 1a98c7c1-4f18-42b1-a5df-aec07b4b116d
# 183
# 18
# COVISHIELD
# MMC Ulliyeri
# 56367548-5261-4168-901d-54e328acf409
# 192
# 18
# COVISHIELD
# Starcare Hospital Kozhikode
# 252f217b-27a4-45d2-ab99-61bb53e62736
# 371
# 18
# COVISHIELD
# Starcare Hospital Kozhikode
# 8f8433f0-89a5-4859-b0b9-a91e1152a9f9
# 395
# 18
# COVISHIELD
# Starcare Hospital Kozhikode
# 9acca523-8786-4893-882c-f9f6d928760f
# 423
# 18
# COVISHIELD
# IQRAA Clinic Kinassery
# 57cebdf7-5ae1-4acc-a8d5-ca09853e4ffc
# 672
# 18
# COVISHIELD
# Iqraa International Hospital
# 8ed56cc9-366f-4fc1-a356-f57691b5fe07
# 1997
# 18
# COVISHIELD
# Iqraa International Hospital
# 0ca54087-607c-415b-a044-59fd1bb3abef
# 1914
# 18
# COVISHIELD
# Iqraa International Hospital
# a4274013-6707-4cbc-b57e-56e4dd0830f1
# 1986
# 18
# COVISHIELD
# Iqraa International Hospital
# 16cbb37d-9620-433a-90e8-f0ce7b414218
# 1990
# 18
# COVISHIELD
# Iqraa International Hospital
# 2c73961f-d43a-4bbc-9820-cb9cd17becd6
# 1998
# 18
# COVISHIELD
# Iqraa International Hospital
# 044646d9-ac80-4b3a-88e3-18cea0e8680c
# 1995
# 18
# COVISHIELD
# Iqraa International Hospital
# 6ea8ca2d-067b-4499-9a3e-f91684cb52af
# 1996
# 18
# COVISHIELD
# Email sent to rahul.santhosh@btech.christuniversity.in From rahulpythonprog@gmail.com
